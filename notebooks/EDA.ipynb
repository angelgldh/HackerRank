# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def make_it_categorical(df, is_phase1 = True):

  factor_columns = ["sex","race","marital_status","patient_regional_location","age_group",
                     "Conjuctivitis", "Acute_upper_respiratory_infection", "Influenza","Pneumonia","Bronchitis"
                     ,"Acute_lower_respiratory_infection_other"
                     ,"Rhinitis"
                     ,"Other_COPD"
                     ,"Asthma"
                     ,"Symptoms_and_signs__circulatory_and_respiratory"
                     ,"Symptoms_and_signs__digestive_system_and_abdomen"
                     ,"Symptoms_and_signs__skin_and_subcutaneous_tissue"
                     ,"Symptoms_and_signs__cognition_perception_emotional_state_and_behaviour"
                     ,"General_symptoms_and_signs"
                     ,"COVID19_related"
                     ,"any_symptom"
                     ,"Acute_myocardial_infarction"
                     ,"Hystory_myocardial_infarction"
                     ,"Congestive_heart_failure"
                     ,"Peripheral_Vascular","CVD","COPD","Dementia","Paralysis","Diabetes","Diabetes_complications"
                     ,"Renal_disease"
                     ,"mild_liver_disease"
                     ,"moderate_liver_disease"
                     ,"Peptic_Ulcer_Disease"
                     ,"rheuma_disease"
                     ,"AIDS"
                     ,"Asthma_chronic"
                     ,"calendar_year"
                     ,"healthcare_seeking"
                     ,"influenza_vaccine",
                     "key_comorbidities",
                     "n_tests_that_day"
                     ,"any_immunodeficiency"
                     , 'tumor_indicator'
                     ,'tumor_last_year'
                     ,'is_metastatic']
  if is_phase1:
    factor_columns.append('RSV_test_result')

  # Option A: for loop
  # for column_name in factor_columns:
  #   if column_name in df.columns:
  #     df[column_name] = df[column_name].astype('categorical')

  # Option B: slightly optimized
  factor_columns_set = set(factor_columns)
  columns_to_categorize = list(factor_columns_set.intersection(set(df.columns)))

  df[columns_to_categorize] = df[columns_to_categorize].apply(lambda x : x.astype('category'))

  return df

# %%
def summary_function_rsv(df, is_phase1 = True):

  factor_columns = ["sex","race","marital_status","patient_regional_location","age_group",
                     "Conjuctivitis", "Acute_upper_respiratory_infection", "Influenza","Pneumonia","Bronchitis"
                     ,"Acute_lower_respiratory_infection_other"
                     ,"Rhinitis"
                     ,"Other_COPD"
                     ,"Asthma"
                     ,"Symptoms_and_signs__circulatory_and_respiratory"
                     ,"Symptoms_and_signs__digestive_system_and_abdomen"
                     ,"Symptoms_and_signs__skin_and_subcutaneous_tissue"
                     ,"Symptoms_and_signs__cognition_perception_emotional_state_and_behaviour"
                     ,"General_symptoms_and_signs"
                     ,"COVID19_related"
                     ,"any_symptom"
                     ,"Acute_myocardial_infarction"
                     ,"Hystory_myocardial_infarction"
                     ,"Congestive_heart_failure"
                     ,"Peripheral_Vascular","CVD","COPD","Dementia","Paralysis","Diabetes","Diabetes_complications"
                     ,"Renal_disease"
                     ,"mild_liver_disease"
                     ,"moderate_liver_disease"
                     ,"Peptic_Ulcer_Disease"
                     ,"rheuma_disease"
                     ,"AIDS"
                     ,"Asthma_chronic"
                     ,"calendar_year"
                     ,"healthcare_seeking"
                     ,"influenza_vaccine",
                     "key_comorbidities",
                     "n_tests_that_day"
                     ,"any_immunodeficiency"
                     , 'tumor_indicator'
                     ,'tumor_last_year'
                     ,'is_metastatic']

  if is_phase1:
    factor_columns.append('RSV_test_result')

  non_factor_columns = [column_name for column_name in df.columns if column_name not in factor_columns]

  print(df[non_factor_columns].describe())
  print('\n')

  for col in factor_columns:
    print(f'Column: {col}')
    print(df[col].value_counts())
    print('\n')

# %%
datasets_path = ''

# %%
rsv_predictors_phase1_df = pd.read_csv(datasets_path + '/rsv_predictors_df_phase1_v3.csv')
rsv_predictors_phase1_df = make_it_categorical(rsv_predictors_phase1_df)

# %%
summary_function_rsv(rsv_predictors_phase1_df)
# Out:
#                 CCI          sine        cosine    n_symptoms  n_encounters  \
# count  86659.000000  86659.000000  8.665900e+04  86659.000000  86659.000000
# mean       2.360297      0.305377  3.863281e-01      2.145963      4.697642
# std        2.432005      0.639752  5.901029e-01      1.702432      6.967793
# min        0.000000     -1.000000 -1.000000e+00      0.000000      1.000000
# 25%        0.000000     -0.239316 -1.608123e-16      1.000000      1.000000
# 50%        2.000000      0.464723  5.680647e-01      2.000000      2.000000
# 75%        4.000000      0.885456  8.854560e-01      3.000000      5.000000
# max       14.000000      1.000000  1.000000e+00     13.000000     79.000000
#
#        prev_positive_rsv  tendency_to_positivity  previous_test_daydiff  \
# count       86659.000000            86659.000000           8.665900e+04
# mean            0.061159                0.030626           3.788330e+05
# std             0.394196                0.127717           4.776361e+06
# min             0.000000                0.000000           0.000000e+00
# 25%             0.000000                0.000000           2.010000e+02
# 50%             0.000000                0.000000           1.095000e+03
# 75%             0.000000                0.000000           1.095000e+03
# max            17.000000                1.000000           2.045088e+08
#
#        n_immunodeficiencies
# count          86659.000000
# mean               0.785181
# std                2.163228
# min                0.000000
# 25%                0.000000
# 50%                0.000000
# 75%                0.000000
# max               30.000000
#
#
# Column: sex
# F          49484
# M          37152
# Unknown       23
# Name: sex, dtype: int64
#
#
# Column: race
# White              50945
# Black              23938
# Unknown             9550
# Asian               1580
# Native American      457
# Pacific              189
# Name: race, dtype: int64
#
#
# Column: marital_status
# Unknown    40200
# Single     30778
# Married    15681
# Name: marital_status, dtype: int64
#
#
# Column: patient_regional_location
# Midwest      29432
# Northeast    25270
# South        16727
# West         15229
# Unknown          1
# Name: patient_regional_location, dtype: int64
#
#
# Column: age_group
# 51-55    13508
# 18-25    13322
# 46-50    13176
# 31-35    11282
# 36-40    11063
# 41-45    10775
# 26-30    10390
# 56-60     3143
# Name: age_group, dtype: int64
#
#
# Column: Conjuctivitis
# 0    86158
# 1      501
# Name: Conjuctivitis, dtype: int64
#
#
# Column: Acute_upper_respiratory_infection
# 0    67922
# 1    18737
# Name: Acute_upper_respiratory_infection, dtype: int64
#
#
# Column: Influenza
# 0    74310
# 1    12349
# Name: Influenza, dtype: int64
#
#
# Column: Pneumonia
# 0    68000
# 1    18659
# Name: Pneumonia, dtype: int64
#
#
# Column: Bronchitis
# 0    81555
# 1     5104
# Name: Bronchitis, dtype: int64
#
#
# Column: Acute_lower_respiratory_infection_other
# 0    86261
# 1      398
# Name: Acute_lower_respiratory_infection_other, dtype: int64
#
#
# Column: Rhinitis
# 0    84847
# 1     1812
# Name: Rhinitis, dtype: int64
#
#
# Column: Other_COPD
# 0    79921
# 1     6738
# Name: Other_COPD, dtype: int64
#
#
# Column: Asthma
# 0    72579
# 1    14080
# Name: Asthma, dtype: int64
#
#
# Column: Symptoms_and_signs__circulatory_and_respiratory
# 0    43693
# 1    42966
# Name: Symptoms_and_signs__circulatory_and_respiratory, dtype: int64
#
#
# Column: Symptoms_and_signs__digestive_system_and_abdomen
# 0    70483
# 1    16176
# Name: Symptoms_and_signs__digestive_system_and_abdomen, dtype: int64
#
#
# Column: Symptoms_and_signs__skin_and_subcutaneous_tissue
# 0    81391
# 1     5268
# Name: Symptoms_and_signs__skin_and_subcutaneous_tissue, dtype: int64
#
#
# Column: Symptoms_and_signs__cognition_perception_emotional_state_and_behaviour
# 0    82296
# 1     4363
# Name: Symptoms_and_signs__cognition_perception_emotional_state_and_behaviour, dtype: int64
#
#
# Column: General_symptoms_and_signs
# 0    49151
# 1    37508
# Name: General_symptoms_and_signs, dtype: int64
#
#
# Column: COVID19_related
# 0    85351
# 1     1308
# Name: COVID19_related, dtype: int64
#
#
# Column: any_symptom
# 1    74656
# 0    12003
# Name: any_symptom, dtype: int64
#
#
# Column: Acute_myocardial_infarction
# 0    80652
# 1     6007
# Name: Acute_myocardial_infarction, dtype: int64
#
#
# Column: Hystory_myocardial_infarction
# 0    82642
# 1     4017
# Name: Hystory_myocardial_infarction, dtype: int64
#
#
# Column: Congestive_heart_failure
# 0    70859
# 1    15800
# Name: Congestive_heart_failure, dtype: int64
#
#
# Column: Peripheral_Vascular
# 0    76008
# 1    10651
# Name: Peripheral_Vascular, dtype: int64
#
#
# Column: CVD
# 0    76958
# 1     9701
# Name: CVD, dtype: int64
#
#
# Column: COPD
# 0    46454
# 1    40205
# Name: COPD, dtype: int64
#
#
# Column: Dementia
# 0    85986
# 1      673
# Name: Dementia, dtype: int64
#
#
# Column: Paralysis
# 0    81545
# 1     5114
# Name: Paralysis, dtype: int64
#
#
# Column: Diabetes
# 0    65430
# 1    21229
# Name: Diabetes, dtype: int64
#
#
# Column: Diabetes_complications
# 0    74253
# 1    12406
# Name: Diabetes_complications, dtype: int64
#
#
# Column: Renal_disease
# 0    69859
# 1    16800
# Name: Renal_disease, dtype: int64
#
#
# Column: mild_liver_disease
# 0    69980
# 1    16679
# Name: mild_liver_disease, dtype: int64
#
#
# Column: moderate_liver_disease
# 0    82590
# 1     4069
# Name: moderate_liver_disease, dtype: int64
#
#
# Column: Peptic_Ulcer_Disease
# 0    83670
# 1     2989
# Name: Peptic_Ulcer_Disease, dtype: int64
#
#
# Column: rheuma_disease
# 0    80833
# 1     5826
# Name: rheuma_disease, dtype: int64
#
#
# Column: AIDS
# 0    81215
# 1     5444
# Name: AIDS, dtype: int64
#
#
# Column: Asthma_chronic
# 0    59728
# 1    26931
# Name: Asthma_chronic, dtype: int64
#
#
# Column: calendar_year
# 2019    20308
# 2018    19752
# 2017    13799
# 2016     9418
# 2020     4886
# 2015     4853
# 2021     4412
# 2014     3324
# 2022     2449
# 2013     1870
# 2012      966
# 2011      500
# 2010       85
# 2009       21
# 2008        9
# 2007        4
# 2004        2
# 2000        1
# Name: calendar_year, dtype: int64
#
#
# Column: healthcare_seeking
# 0    50848
# 1    35811
# Name: healthcare_seeking, dtype: int64
#
#
# Column: influenza_vaccine
# 0    76388
# 1    10271
# Name: influenza_vaccine, dtype: int64
#
#
# Column: key_comorbidities
# 0    46224
# 1    26585
# 2    13850
# Name: key_comorbidities, dtype: int64
#
#
# Column: n_tests_that_day
# 1    85457
# 2     1202
# Name: n_tests_that_day, dtype: int64
#
#
# Column: any_immunodeficiency
# 0    70140
# 1    16519
# Name: any_immunodeficiency, dtype: int64
#
#
# Column: tumor_indicator
# 0    80215
# 1     6444
# Name: tumor_indicator, dtype: int64
#
#
# Column: tumor_last_year
# 0    83461
# 1     3198
# Name: tumor_last_year, dtype: int64
#
#
# Column: is_metastatic
# 0    85829
# 1      830
# Name: is_metastatic, dtype: int64
#
#
# Column: RSV_test_result
# Negative    84005
# Positive     2654
# Name: RSV_test_result, dtype: int64

# %%
numeric_columns = [column_name for column_name in df.columns if column_name not in factor_columns]

# %%
categorical_cols = ['sex', 'race', 'calendar_year']

for col in categorical_cols:
    print(f"Column: {col}")
    print(df[col].value_counts())
    print("\n")
# Out:
# Column: sex
# F          49484
# M          37152
# Unknown       23
# Name: sex, dtype: int64
#
#
# Column: race
# White              50945
# Black              23938
# Unknown             9550
# Asian               1580
# Native American      457
# Pacific              189
# Name: race, dtype: int64
#
#
# Column: calendar_year
# 2019    20308
# 2018    19752
# 2017    13799
# 2016     9418
# 2020     4886
# 2015     4853
# 2021     4412
# 2014     3324
# 2022     2449
# 2013     1870
# 2012      966
# 2011      500
# 2010       85
# 2009       21
# 2008        9
# 2007        4
# 2004        2
# 2000        1
# Name: calendar_year, dtype: int64
